# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

X = np.random.rand(100,1) * 10
y = 4 * X + 3 + np.random.randn(100,1)

# %%
def forward(X, w, b):
    return X @ w + b

# %%
def compute_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
def compute_gradients(X, y, y_pred):
    n = len(y)
    
    dw = (2/n) * (X.T @ (y_pred - y))
    db = (2/n) * np.sum(y_pred - y)
    
    return dw, db

# %%
def train(X, y, lr=0.01, epochs=500):
    
    n_samples, n_features = X.shape
    
    w = np.zeros((n_features, 1))
    b = 0
    
    losses = []
    
    for epoch in range(epochs):
        
        y_pred = forward(X, w, b)
        
        loss = compute_loss(y, y_pred)
        losses.append(loss)
        
        dw, db = compute_gradients(X, y, y_pred)
        
        w -= lr * dw
        b -= lr * db
        
        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Loss: {loss:.4f}")
    
    return w, b, losses

# %%
w, b, losses = train(X, y, lr=0.01, epochs=2000)

print("Learned weight:", w)
print("Learned bias:", b)
# Out:
# Epoch 0 | Loss: 613.2945
# Epoch 100 | Loss: 1.4121
# Epoch 200 | Loss: 1.0057
# Epoch 300 | Loss: 0.8720
# Epoch 400 | Loss: 0.8281
# Epoch 500 | Loss: 0.8137
# Epoch 600 | Loss: 0.8089
# Epoch 700 | Loss: 0.8073
# Epoch 800 | Loss: 0.8068
# Epoch 900 | Loss: 0.8067
# Epoch 1000 | Loss: 0.8066
# Epoch 1100 | Loss: 0.8066
# Epoch 1200 | Loss: 0.8066
# Epoch 1300 | Loss: 0.8066
# Epoch 1400 | Loss: 0.8066
# Epoch 1500 | Loss: 0.8066
# Epoch 1600 | Loss: 0.8066
# Epoch 1700 | Loss: 0.8066
# Epoch 1800 | Loss: 0.8066
# Epoch 1900 | Loss: 0.8066
# Learned weight: [[3.95402845]]
# Learned bias: 3.215058594714116

# %%
plt.plot(losses)
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
y_pred = forward(X, w, b)

plt.scatter(X, y, label="True data")
plt.plot(X, y_pred, color="red", label="Predicted")
plt.legend()
plt.show()
